# %%
"|IMPORT PACKAGES|"
import pandas             as pd
from   bokeh.plotting     import show, figure
from   bokeh.io           import show, output_notebook
from   bokeh.io           import curdoc
from   bokeh.models       import LinearAxis, Range1d
from   bokeh.models       import ColumnDataSource
from   bokeh.models       import NumeralTickFormatter
from   bokeh.models.tools import HoverTool

# %%
"|IMPORT DATA|"
path = r'https://github.com/ncachanosky/research/blob/master/Economic%20Series/'
file = r'Resumen%20Estadistico%20-%20Argentina.xlsx?raw=true'
IO   = path + file

sheet = 'PBI-K vs PBI'

data = pd.read_excel(IO, sheet_name = sheet, usecols="U:AG", skiprows=1, nrows=11) # Be patient...
data = data/1000
data["BIAS"] = data["PBI_K"]/data["PBI"]

cds = ColumnDataSource(data)

# %%
"|CHECK DATA|"
data
# Out:
#     YEAR            PBI              C             G              I  \
# 0   2004  485115.195250  312081.885835  53918.788645   85143.879409
# 1   2005  528238.579796  336596.848128  59232.719843   96480.623130
# 2   2006  571250.596212  370298.656414  61437.671454  106728.958894
# 3   2007  622753.090935  405650.271095  66248.105090  127450.832325
# 4   2008  648247.739968  433396.659673  69570.499543  137822.643984
# 5   2009  609266.299935  414347.023268  73490.278328  101720.730257
# 6   2010  672347.097243  458716.085799  77497.097371  138503.477162
# 7   2011  713679.543202  499340.938166  81034.769761  163927.291952
# 8   2012  706165.393635  498903.520764  83473.345880  151962.575708
# 9   2013  722424.739955  522064.165050  87913.007558  153183.041791
# 10  2014  703941.665917  494945.835899  90503.207668  147825.292837
#
#                 X              M       PBI_K         C_K        G_K  \
# 0   115688.425447   81717.784031  535828.336  353767.400  52034.726
# 1   130596.996622   94668.607927  585265.574  387427.544  56141.895
# 2   137859.760997  105074.451548  634283.013  417918.359  58684.027
# 3   149115.254877  125711.372453  684807.291  456119.834  63310.474
# 4   150218.520641  142760.583873  705864.742  479972.608  66098.976
# 5   136177.435596  116469.167514  706217.847  496463.800  71713.646
# 6   155101.896197  157471.459286  772966.580  536597.569  76880.254
# 7   161536.786618  192160.243295  837791.047  591541.621  83656.525
# 8   154900.352503  183074.401220  844508.122  617256.652  88597.059
# 9   149447.487837  190182.962280  868875.153  644080.453  92310.433
# 10  139017.297373  168349.967860  872952.411  640816.480  94875.857
#
#            I_K         X_K         M_K      BIAS
# 0    96443.944  115204.402   81622.127  1.104538
# 1   107205.900  129649.554   95159.303  1.107957
# 2   126431.475  136784.109  105534.942  1.110341
# 3   145879.960  147557.118  128060.091  1.099645
# 4   155669.915  149166.712  145043.465  1.088881
# 5   120213.036  135145.666  117318.302  1.159128
# 6   163588.340  154095.080  158194.651  1.149654
# 7   193716.004  162773.809  193896.908  1.173904
# 8   167100.524  153589.923  182036.069  1.195907
# 9   175288.769  147499.360  188528.765  1.202721
# 10  164279.784  135503.507  164729.923  1.240092

# %%
"|BUILD PLOT|"

#BUILD FIGURE
p = figure(title        = "PBI-K vs PBI",
           x_axis_label = "Año",
           y_axis_label = "Miles de millones de pesos (2004)",
           #x_range      = (1994, 2019),
           #y_range      = (-15, 15),
           plot_height  =  600,
           plot_width   = 1000)

p.toolbar_location = "above"
p.toolbar.autohide = True
p.add_tools(HoverTool(tooltips = [("Año", "@YEAR"), ("%PBI (ARKLEMS)", "@PBI"), ("%PBI (K)", "@PBI_K"), ("Sobre estimacion", "@BIAS")]))

#AXIS 1 (LEFT)
p.line("YEAR", "PBI"  , legend_label="PBI (ARKLEMS)", line_color="blue", alpha=0.50, line_width=2, source=cds)
p.line("YEAR", "PBI_K", legend_label="PBI (K)"      , line_color="red" , alpha=0.50, line_width=2, source=cds)

p.circle("YEAR", "PBI"  , color="blue", fill_alpha = 0.50, source=cds, size=7)
p.circle("YEAR", "PBI_K", color="red" , fill_alpha = 0.50, source=cds, size=7)


p.yaxis[0].formatter = NumeralTickFormatter(format="$0,0")



#AXIS 2 (RIGHT
p.extra_y_ranges={"y2": Range1d(start=0, end=2)}
p.add_layout(LinearAxis(y_range_name = "y2", axis_label = "Sobre estimacion PBI (K)"), "right")
p.vbar("YEAR", top="BIAS", color="green", width=0.50, fill_alpha = 0.50, y_range_name = "y2", source=cds, 
       legend_label="Sobre estimacion del PBI (K)", hover_alpha=1)

#LEGEND
p.legend.location    = "top_left"
p.legend.orientation = "horizontal"
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-49ebe82aca8c> in <module>
#      15
#      16 #AXIS 1 (LEFT)
# ---> 17 p.line("YEAR", "PBI"/1000  , legend_label="PBI (ARKLEMS)", line_color="blue", alpha=0.50, line_width=2, source=cds)
#      18 p.line("YEAR", "PBI_K"/1000, legend_label="PBI (K)"      , line_color="red" , alpha=0.50, line_width=2, source=cds)
#      19
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
data["PBI"]
# Out:
# 0     485115.195250
# 1     528238.579796
# 2     571250.596212
# 3     622753.090935
# 4     648247.739968
# 5     609266.299935
# 6     672347.097243
# 7     713679.543202
# 8     706165.393635
# 9     722424.739955
# 10    703941.665917
# Name: PBI, dtype: float64
