# %%
"|IMPORT PACKAGES|"
import pandas             as pd
import datetime
from   bokeh.plotting     import show, figure, output_file, save
from   bokeh.io           import show, output_notebook, curdoc, export_png
from   bokeh.models       import ColumnDataSource,LinearAxis, Range1d, NumeralTickFormatter, LabelSet, Label, BoxAnnotation, DatetimeTickFormatter, Legend, LegendItem
from   bokeh.models.tools import HoverTool

# %%
"|IMPORT DATA|"
path = r'https://github.com/ncachanosky/research/blob/master/Economic%20Series/'
file = r'Resumen%20Estadistico%20-%20Argentina.xlsx?raw=true'
IO   = path + file

sheet = 'REC TRIB'

data = pd.read_excel(IO, sheet_name = sheet, skiprows=4, engine='openpyxl')

# %%
data["G/T"]=data[" Ganancias"]/data[" Total recursos tributarios"]*100
data["IVA/T"]=data[" IVA"]/data[" Total recursos tributarios"]*100
data["TC/T"]=data["Total Combustibles"]/data[" Total recursos tributarios"]*100
data["BP/T"]=data[" Bienes Personales"]/data[" Total recursos tributarios"]*100
data["EX/T"]=data[" Derechos de Exportación"]/data[" Total recursos tributarios"]*100
data["IM/T"]=data[" Derechos de Importación y Otros"]/data[" Total recursos tributarios"]*100
data["SS/T"]=data[" Sistema Seguridad Social"]/data[" Total recursos tributarios"]*100
data["O/T"]=(100-(data["G/T"]+data["IVA/T"]+data["TC/T"]+data["BP/T"]+data["EX/T"]+data["IM/T"]+data["SS/T"]))

# %%
data
# Out:
#        Anuales      Ganancias  Ganancias DGI  Ganancias DGA            IVA  \
# 0   1997-01-01     631.742777     595.211071      36.531706    1804.643116
# 1   1997-02-01     532.715215     502.176984      30.538231    1588.989215
# 2   1997-03-01     527.815580     493.733930      34.081649    1585.993095
# 3   1997-04-01     747.628032     707.201749      40.426283    1613.221363
# 4   1997-05-01    1288.790506    1247.111070      41.679436    1751.580951
# ..         ...            ...            ...            ...            ...
# 286 2020-11-01  156601.783078  146786.671961    9815.111118  192369.680720
# 287 2020-12-01  166887.495101  156324.725494   10562.769607  203984.850810
# 288 2021-01-01  149584.909933  138275.728018   11309.181915  232831.605171
# 289 2021-02-01  146916.970035  136010.047214   10906.922821  212043.376502
# 290 2021-03-01  140840.462181  126543.388380   14297.073801  247490.150448
#
#            IVA DGI  Devoluciones (-)         IVA DGA   Reintegros (-)  \
# 0      1343.520910         129.830982     590.953188        50.075759
# 1      1203.876140         113.179656     498.292731        55.916665
# 2      1161.529626         113.717171     538.180640        65.162606
# 3      1168.337455         195.771459     640.655368        58.552101
# 4      1222.086514         133.042314     662.536751        51.807450
# ..             ...                ...            ...              ...
# 286  123604.386359        2600.000000   71365.294361      2600.000000
# 287  132324.348266        6100.000000   77760.502544      3010.000000
# 288  157595.066356        7500.000000   82736.538816      5500.000000
# 289  139813.254365        3600.000000   75830.122137      4800.000000
# 290  150380.729046        3100.000000  100209.421401      4400.000000
#
#       Internos Coparticipados  ...   Total recursos tributarios  \
# 0                  130.054730  ...                  4353.758957
# 1                  133.373454  ...                  3634.762208
# 2                  152.661073  ...                  3531.360254
# 3                  112.592828  ...                  3939.777343
# 4                  130.674918  ...                  4600.930508
# ..                        ...  ...                          ...
# 286              17497.804475  ...                648976.294488
# 287              16592.456377  ...                679640.691501
# 288              17737.511620  ...                772859.817460
# 289              19944.847639  ...                716595.439859
# 290              21452.168277  ...                763857.821536
#
#       Total con capitalización y transitorios        G/T      IVA/T      TC/T  \
# 0                                 4741.026137  14.510284  41.450230  8.300813
# 1                                 3916.991448  14.656123  43.716456  8.719305
# 2                                 3800.751574  14.946523  44.911677  7.523741
# 3                                 4229.967963  18.976403  40.947019  8.534936
# 4                                 4897.253638  28.011519  38.070146  5.672279
# ..                                        ...        ...        ...       ...
# 286                             648976.294488  24.130586  29.642020  2.902360
# 287                             679640.691501  24.555254  30.013631  4.151763
# 288                             772859.817460  19.354727  30.125981  2.457411
# 289                             716595.439859  20.502080  29.590389  3.499060
# 290                             763857.821536  18.438047  32.400028  3.125105
#
#          BP/T       EX/T      IM/T       SS/T        O/T
# 0    0.193832   0.011156  5.338051  26.545855   3.649779
# 1    0.105396   0.001217  5.077179  23.440418   4.283906
# 2    0.129951   0.000869  5.606502  21.973144   4.907593
# 3    1.756348   0.031159  6.131057  20.928170   2.694909
# 4    1.496057   0.037051  5.114618  18.227635   3.370697
# ..        ...        ...       ...        ...        ...
# 286  3.006495   6.203537  3.208246  19.691677  11.215079
# 287  3.868261   4.169580  3.479519  19.545990  10.216002
# 288  0.731344  10.276536  3.162572  24.359513   9.531915
# 289  2.947927   8.991679  3.029290  21.754267   9.685308
# 290  0.954443   9.326731  3.821237  21.037948  10.896460
#
# [291 rows x 40 columns]

# %%
cds = ColumnDataSource(data)

p = figure(title = "EL HUB ECONÓMICO | PARTICIPACIÓN DE IMPUESTOS EN RECAUDACIÓN",
           y_axis_label = "Participación por impuesto", 
           plot_height  = 600,
           plot_width   = 700)

p.toolbar_location = "right"
p.toolbar.autohide = True

colors=['black',     # 1
        'blue' ,     # 2
        'red'  ,     # 3
        'green',     # 4
        'slateblue', # 5
        'teal',      # 6
        'tan',       # 7
        'plum'  ]    # 8

p1 = p.varea_stack(["G/T","IVA/T","TC/T","BP/T","EX/T","IM/T","SS/T","O/T"], x='Anuales', color=colors, fill_alpha=0.5, muted_alpha=0.20, source=cds)
p2 = p.vline_stack(["G/T","IVA/T","TC/T","BP/T","EX/T","IM/T","SS/T","O/T"], x='Anuales', color=colors, line_alpha=1.0, muted_alpha=0.20, source=cds
                  
                  )



legends=["Ganancias",
        "IVA",
        "Combustibles",
        "Bienes Personales",
        "Derechos de Exportación",
        "Derechos de Importación",
        "Seguridad Social",
        "Otros impuestos"]
legend1 = Legend(items=[(legends[ 0], [p1[ 0]]),
                        (legends[ 1], [p1[ 1]]),
                        (legends[ 2], [p1[ 2]]),
                        (legends[ 3], [p1[ 3]]),
                       (legends[ 4], [p1[ 4]])], orientation="horizontal", click_policy='mute')

legend2 = Legend(items=[(legends[ 5], [p1[ 5]]),
                       (legends[ 6], [p1[ 6]]),
                       (legends[ 7], [p1[ 7]])], orientation="horizontal", click_policy='mute')

p.add_layout(legend1, "below")
p.add_layout(legend2, "below")


#p.xaxis[0].formatter = NumeralTickFormatter(format=)   #Buscar función para la fecha.

show(p)
